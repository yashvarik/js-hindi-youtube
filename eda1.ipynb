# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\yash\Downloads\VideoGamesSales (1).csv")

# %%
df.head()
# Out:
#    Game_Rank                      Name Platform  Year Month         Genre  \
# 0          1                Wii Sports      Wii  2010   Jan        Sports
# 1          2         Super Mario Bros.      NES  2010   Feb      Platform
# 2          3            Mario Kart Wii      Wii  2010   Mar        Racing
# 3          4         Wii Sports Resort      Wii  2010   Apr        Sports
# 4          5  Pokemon Red/Pokemon Blue       GB  2010   May  Role-Playing
#
#   Publisher        Country        City       State   Region  NA_Sales  \
# 0  Nintendo  United States   Fairfield  California     West     41.49
# 1  Nintendo  United States     Edmonds  Washington     West     29.08
# 2  Nintendo  United States  Louisville    Kentucky    South     15.85
# 3  Nintendo  United States  Round Rock       Texas  Central     15.75
# 4  Nintendo  United States   Nashville   Tennessee    South     11.27
#
#    Global_Sales  NA_Profit  Global_Profit
# 0         82.74     12.447         24.822
# ...

# %%
df.head(20)
# Out:
#     Game_Rank                                          Name Platform  Year  \
# 0           1                                    Wii Sports      Wii  2010
# 1           2                             Super Mario Bros.      NES  2010
# 2           3                                Mario Kart Wii      Wii  2010
# 3           4                             Wii Sports Resort      Wii  2010
# 4           5                      Pokemon Red/Pokemon Blue       GB  2010
# 5           6                                        Tetris       GB  2010
# 6           7                         New Super Mario Bros.       DS  2010
# 7           8                                      Wii Play      Wii  2010
# 8           9                     New Super Mario Bros. Wii      Wii  2010
# 9          10                                     Duck Hunt      NES  2010
# 10         11                                    Nintendogs       DS  2010
# ...

# %%
df.tail()
# Out:
#       Game_Rank                                       Name Platform  Year  \
# 5888       5890                   Crazy Taxi: Catch a Ride      GBA  2017
# 5889       5891                               MySims Party       DS  2017
# 5890       5892  Harry Potter and the Order of the Phoenix     X360  2017
# 5891       5893                  Skylanders: SuperChargers      PS4  2017
# 5892       5894               Macross Digital Mission VF-X       PS  2017
#
#      Month       Genre           Publisher    Country    City  \
# 5888   Sep      Racing                 THQ  Australia  Sydney
# 5889   Oct  Simulation     Electronic Arts  Australia  Sydney
# 5890   Nov      Action     Electronic Arts  Australia  Sydney
# 5891   Dec      Action          Activision  Australia  Sydney
# 5892   Jan  Simulation  Namco Bandai Games  Australia  Sydney
#
#                 State Region  NA_Sales  Global_Sales  NA_Profit  Global_Profit
# ...

# %%
df.isnull().sum()
# Out:
# Game_Rank         0
# Name              0
# Platform          0
# Year              0
# Month             0
# Genre             0
# Publisher        12
# Country           0
# City              0
# State             0
# Region            0
# NA_Sales          0
# Global_Sales      0
# NA_Profit         0
# Global_Profit     0
# dtype: int64

# %%
df['Publisher']
# Out:
# 0                 Nintendo
# 1                 Nintendo
# 2                 Nintendo
# 3                 Nintendo
# 4                 Nintendo
#                ...
# 5888                   THQ
# 5889       Electronic Arts
# 5890       Electronic Arts
# 5891            Activision
# 5892    Namco Bandai Games
# Name: Publisher, Length: 5893, dtype: object

# %%
df.describe()
# Out:
#          Game_Rank         Year     NA_Sales  Global_Sales    NA_Profit  \
# count  5893.000000  5893.000000  5893.000000   5893.000000  5893.000000
# mean   2947.889191  2013.200407     0.650989      1.320877     0.195297
# std    1701.477595     2.220695     1.280881      2.418291     0.384264
# min       1.000000  2010.000000     0.000000      0.300000     0.000000
# 25%    1475.000000  2011.000000     0.200000      0.440000     0.060000
# 50%    2948.000000  2013.000000     0.360000      0.690000     0.108000
# 75%    4421.000000  2015.000000     0.680000      1.330000     0.204000
# max    5894.000000  2017.000000    41.490000     82.740000    12.447000
#
#        Global_Profit
# count    5893.000000
# mean        0.396263
# std         0.725487
# min         0.090000
# 25%         0.132000
# 50%         0.207000
# 75%         0.399000
# max        24.822000

# %%
data=pd.read_csv(r"C:\Users\yash\Downloads\Amazon Sale Report.csv\Amazon Sale Report.csv")
# Out:
# C:\Users\yash\AppData\Local\Temp\ipykernel_3640\1466634947.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r"C:\Users\yash\Downloads\Amazon Sale Report.csv\Amazon Sale Report.csv")

# %%
data
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data.head(10)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
# 5      5  404-1490984-4578765  04-30-22                       Shipped
# 6      6  408-5748499-6859555  04-30-22                       Shipped
# 7      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8      8  407-5443024-5233168  04-30-22                     Cancelled
# 9      9  402-4393761-0311520  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style                  SKU  \
# 0   Merchant      Amazon.in           Standard   SET389       SET389-KR-NP-S
# ...

# %%
data.tail(10)
# Out:
#          index             Order ID      Date     Status Fulfilment  \
# 128965  128965  408-5154281-4593912  05-31-22  Cancelled     Amazon
# 128966  128966  406-9812666-2474761  05-31-22    Shipped     Amazon
# 128967  128967  404-5182288-1653947  05-31-22  Cancelled     Amazon
# 128968  128968  403-7059995-7618722  05-31-22    Shipped     Amazon
# 128969  128969  404-3802633-7250760  05-31-22  Cancelled     Amazon
# 128970  128970  406-6001380-7673107  05-31-22    Shipped     Amazon
# 128971  128971  402-9551604-7544318  05-31-22    Shipped     Amazon
# 128972  128972  407-9547469-3152358  05-31-22    Shipped     Amazon
# 128973  128973  402-6184140-0545956  05-31-22    Shipped     Amazon
# 128974  128974  408-7436540-8728312  05-31-22    Shipped     Amazon
#
#        Sales Channel  ship-service-level    Style              SKU  \
# 128965      Amazon.in          Expedited    J0119    J0119-TP-XXXL
# 128966      Amazon.in          Expedited   SET224  SET224-KR-NP-XS
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                      bool
# fulfilled-by           object
# Unnamed: 22            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %%
len(data.columns)
# Out:
# 24

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128970  128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
data['Amount'].max()
# Out:
# 5584.0

# %%
data['Amount'].min()
# Out:
# 0.0

# %%
data['Amount'].mean()
# Out:
# np.float64(648.5614647631621)

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
len(data[data['Status']=='Shipped'])
# Out:
# 77804

# %%
data.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')

# %%
len(data[data['Category']=='Top'])
# Out:
# 10622

# %%
data[data['Order ID']==]
