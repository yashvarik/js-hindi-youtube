# %%
from langchain_ollama.chat_models import ChatOllama

# %%
chat=ChatOllama(model='llama3.1:8b')

# %%
response=chat.invoke(""" i just got the dog can you please suggest the name for it""")

# %%
response
# Out:
# AIMessage(content="Congratulations on your new furry family member!\n\nI'd be happy to help you come up with some name suggestions. Before I start, could you please tell me a bit more about your dog? For example:\n\n* What breed or mix is your dog?\n* What's its size (small, medium, large)?\n* Does it have any distinctive features (e.g., coat color, eye shape, floppy ears)?\n* Do you prefer a specific theme for the name (e.g., food-related, movie/TV-inspired, literary character)?\n* Is there a particular sound or style you like in names (e.g., short and snappy, long and elegant)?\n\nThis will help me provide more tailored suggestions that fit your dog's personality and characteristics!", additional_kwargs={}, response_metadata={'model': 'llama3.1:8b', 'created_at': '2025-11-26T09:50:58.7483094Z', 'done': True, 'done_reason': 'stop', 'total_duration': 45920116100, 'load_duration': 9269015300, 'prompt_eval_count': 23, 'prompt_eval_duration': 2313367100, 'eval_count': 150, 'eval_duratio
# ...

# %%
print(response.content)
# Out:
# Congratulations on your new furry family member!
#
# I'd be happy to help you come up with some name suggestions. Before I start, could you please tell me a bit more about your dog? For example:
#
# * What breed or mix is your dog?
# * What's its size (small, medium, large)?
# * Does it have any distinctive features (e.g., coat color, eye shape, floppy ears)?
# * Do you prefer a specific theme for the name (e.g., food-related, movie/TV-inspired, literary character)?
# * Is there a particular sound or style you like in names (e.g., short and snappy, long and elegant)?
#
# This will help me provide more tailored suggestions that fit your dog's personality and characteristics!
