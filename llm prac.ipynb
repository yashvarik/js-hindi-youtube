# %%
import ollama
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ollama
#
# ModuleNotFoundError: No module named 'ollama'

# %%
# First, install the ollama package
# !pip install ollama

# Then import it
import ollama

# Note: The '!' syntax works in Jupyter notebooks to run shell commands
# If you're in a regular Python script, you would need to install the package
# before running your script, using 'pip install ollama' in your terminal
# Out:
# ...
#   Using cached pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# ...
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# ...
# Using cached pydantic-2.12.4-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# ...
#
#   Attempting uninstall: pydantic
#
#     Found existing installation: pydantic 1.10.9
#
#    ------------------------ --------------- 3/5 [pydantic]
#     Uninstalling pydantic-1.10.9:
#    ------------------------ --------------- 3/5 [pydantic]
#       Successfully uninstalled pydantic-1.10.9
#    ------------------------ --------------- 3/5 [pydantic]
#    ------------------------ --------------- 3/5 [pydantic]
# ...

# %%
import ollama

# %%
def talk_bot(prompt ,model_name="llama3.1:8b"):
    model=model_name,
    prompt=prompt,
    messages=({
    'role':'user',
    'content':prompt})
    rteutn response=['message'] ['content']
# Out:
#   Cell In[6], line 7
#     rteutn response=['message'] ['content']
#            ^
# SyntaxError: invalid syntax

# %%
def bot(prompt,model_name="llama3.1:8b"):
    response=ollama.chat(
        model=model_name,
        messages=[{
            'role':'system',
            'content':'your a portic bot who give answer in a poem form'},
            
            {'role':'user',
            'content':prompt}])
    return response ['message'] ['content']

# %%
bot("what is a pencile")
# Out:
# "A tool so fine and true,\nUsed for writing, drawing anew.\nA stick with lead at its heart,\nHelping thoughts and dreams to take part.\n\nIts shape is slender, long and thin,\nErgonomic design to fit within,\nThe hand that holds it, guiding the way,\nTo create lines and marks each day.\n\nWith every stroke, a new line's born,\nConnecting thoughts, ideas, and morn.\nA pencil's humble form, yet grand,\nA bridge between mind and written land."

# %%
def cherry(prompt,model_name="llama3.1:8b"):
    response=ollama.chat(
        model=model_name,
        messages=[{
            'role':'user',
            'content':prompt}])
    return response ['message'] ['content']

# %%
cherry("what is even number")
# Out:
# "An even number is a whole number that is divisible by 2 without leaving a remainder. In other words, if a number ends in 0, 2, 4, 6, or 8, it's an even number.\n\nExamples of even numbers:\n\n* 2\n* 4\n* 10\n* 24\n* 36\n\nOn the other hand, if a number ends in 1, 3, 5, 7, or 9, it's an odd number.\n\nExamples of odd numbers:\n\n* 1\n* 3\n* 5\n* 7\n* 9\n\nIt's worth noting that even numbers can be positive (e.g., 2, 4) or negative (e.g., -2, -4), and they can also be zero."
