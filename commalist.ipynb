# %%
from langchain_ollama import ChatOllama

# %%
from langchain_core.messages import HumanMessage

# %%
human_m=HumanMessage(content=f"""can you suggest me a healthy desert
   {CommaSeparatedListOutputParser().get_format_instructions()}""")

# %%
chat=ChatOllama(
    model='llama3.1:8b')

# %%
response=chat.invoke([human_m])

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
list_seprated=CommaSeparatedListOutputParser()

# %%
response_parsed=list_seprated.invoke(response)

# %%
response_parsed
# Out:
# ['Here are some healthy dessert options:',
#  'Greek yogurt with honey and walnuts',
#  'Fresh berries with cottage cheese',
#  'Dark chocolate-dipped apricots',
#  'Baked apples with cinnamon',
#  'Chia seed pudding with coconut milk.',
#  'Would you like me to suggest more?']

# %%
from langchain_ollama import ChatOllama

# %%
from langchain_core.messages import HumanMessage

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
chat=ChatOllama(
    model='llama3.1:8b')

# %%
human_mess=HumanMessage(content='who invented the telephone')

# %%
response=chat.invoke([human_mess])

# %%
str_output=StrOutputParser()

# %%
response_parsed=str_output.invoke(response)

# %%
response_parsed
# Out:
# 'A question that\'s been answered in many ways, but with some controversy!\n\nThe invention of the telephone is often credited to Alexander Graham Bell, a Scottish-born inventor and scientist. On March 10, 1876, Bell filed the first patent for a "telephone" at the United States Patent Office, receiving U.S. Patent No. 174,465.\n\nHowever, there are other inventors who contributed to the development of the telephone around the same time. Some notable examples include:\n\n1. **Elisha Gray**, an American inventor, who filed a caveat for a similar device just hours after Bell on March 7, 1876.\n2. **Antonio Meucci**, an Italian inventor, who is said to have developed a "talking telegraph" in the 1840s and possibly even earlier. His work was reportedly influenced by his daughter\'s struggle with deafness.\n3. **Philip Reis**, a German inventor, who built a device that could transmit sound over wires as early as 1861.\n\nSo, while Alexander Graham Bell is often credited with inventing the 
# ...

# %%
response
# Out:
# AIMessage(content='A question that\'s been answered in many ways, but with some controversy!\n\nThe invention of the telephone is often credited to Alexander Graham Bell, a Scottish-born inventor and scientist. On March 10, 1876, Bell filed the first patent for a "telephone" at the United States Patent Office, receiving U.S. Patent No. 174,465.\n\nHowever, there are other inventors who contributed to the development of the telephone around the same time. Some notable examples include:\n\n1. **Elisha Gray**, an American inventor, who filed a caveat for a similar device just hours after Bell on March 7, 1876.\n2. **Antonio Meucci**, an Italian inventor, who is said to have developed a "talking telegraph" in the 1840s and possibly even earlier. His work was reportedly influenced by his daughter\'s struggle with deafness.\n3. **Philip Reis**, a German inventor, who built a device that could transmit sound over wires as early as 1861.\n\nSo, while Alexander Graham Bell is often credited w
# ...

# %%
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
human_message=HumanMessage(content="can you give me a list of smartphone brands")

# %%
response=chat.invoke([human_message])
